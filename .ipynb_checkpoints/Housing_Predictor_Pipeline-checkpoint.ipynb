# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_5_Project\CSV\NYCH.csv')
df
# Out:
#                           address        city     price  bedroom_number  \
# 0                          107-59       111st  640000.0             4.0
# 1                          161-10       122nd  640000.0             5.0
# 2             33-65 14th St #3-9B        14th  450000.0             2.0
# 3                          132-11       157th  429000.0             5.0
# 4       160-21 16th Avenue #6-253        16th  270000.0             2.0
# ...                           ...         ...       ...             ...
# 118761            160-23 16th Ave  whitestone  225000.0             1.0
# 118762                 85-35 75th   woodhaven  825000.0             5.0
# 118763               85-61 Dexter   woodhaven  705000.0             6.0
# 118764                 41-49 57th    woodside  555000.0             2.0
# 118765           63-14 Queens #5B    woodside  750000.0             3.0
#
#         bathroom_number  living_space  zip_code
# 0                   3.0        2000.0     11419
# ...

# %%
df['city'].value_counts().head(40)
# Out:
# city
# Brooklyn            17710
# Staten Island       14460
# Bronx               11636
# New York            11551
# Flushing             6006
# Jamaica              5558
# Buffalo              1426
# Rochester            1374
# Far Rockaway         1366
# Long Island City     1205
# Syracuse              733
# Forest Hills          727
# Yonkers               636
# Schenectady           603
# Albany                518
# Astoria               466
# White Plains          419
# Jackson Heights       373
# Scarsdale             367
# Troy                  351
# Poughkeepsie          347
# Queens                346
# Binghamton            334
# Woodside              316
# Rego Park             293
# Little Neck           286
# Niagara Falls         282
# Bayside               279
# East Elmhurst         276
# Saratoga Springs      272
# Mount Vernon          272
# Utica                 267
# New Rochelle          266
# Bronxville            263
# Middletown            256
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118766 entries, 0 to 118765
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   address          118766 non-null  object
#  1   city             118766 non-null  object
#  2   price            118766 non-null  float64
#  3   bedroom_number   118766 non-null  float64
#  4   bathroom_number  118766 non-null  float64
#  5   living_space     118766 non-null  float64
#  6   zip_code         118766 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 6.3+ MB

# %%
import pandas as pd

# Check if the 'city' column contains any digits
contains_digits = df['city'].str.contains(r'\d', na=False)

# Get rows where 'city' contains digits
rows_with_digits = df[contains_digits]

# Display the rows with city names that contain digits
print(rows_with_digits)
# Out:
#                           address                                city  \
# 0                          107-59                               111st
# 1                          161-10                               122nd
# 2             33-65 14th St #3-9B                                14th
# 3                          132-11                               157th
# 4       160-21 16th Avenue #6-253                                16th
# 5                350 West 42nd St                          350w42ndst
# 6                350 West 42nd St                          350w42ndst
# 7              99-06 58th #APT 3C                              3c Ave
# 8                22-60 #1ST FLOOR                                94th
# 40529                   765 214th                   East 214th Street
# 40530                    415 #H1C                    East 52nd Street
# 50715            5837 Lawrence St  Flushing NY 11355 QueensBoro Hills
# ...

# %%
rows_with_digits
# Out:
#                           address                                city  \
# 0                          107-59                               111st
# 1                          161-10                               122nd
# 2             33-65 14th St #3-9B                                14th
# 3                          132-11                               157th
# 4       160-21 16th Avenue #6-253                                16th
# 5                350 West 42nd St                          350w42ndst
# 6                350 West 42nd St                          350w42ndst
# 7              99-06 58th #APT 3C                              3c Ave
# 8                22-60 #1ST FLOOR                                94th
# 40529                   765 214th                   East 214th Street
# 40530                    415 #H1C                    East 52nd Street
# 50715            5837 Lawrence St  Flushing NY 11355 QueensBoro Hills
# ...
