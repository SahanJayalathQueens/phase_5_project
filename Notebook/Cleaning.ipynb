# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
zil = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_5_Project\CSV\zillow NY for-sale properties.csv')

# Set the display option to show all columns in the info() output
pd.set_option('display.max_info_columns', 1507)  # Set it to the number of columns in your DataFrame

# Now you can use df.info() to display all columns
zil
# Out:
#                                             property_url  property_id  \
# 0      https://www.zillow.com/homedetails/97-Reservoi...   2066966109
# 1      https://www.zillow.com/homedetails/524-County-...     29962801
# 2      https://www.zillow.com/homedetails/32-Brooksid...     29962922
# 3      https://www.zillow.com/homedetails/252-Elmwood...     29971014
# 4      https://www.zillow.com/homedetails/3526-Kentuc...     29974158
# ...                                                  ...          ...
# 96804  https://www.zillow.com/homedetails/333-Lathrop...     32301630
# 96805  https://www.zillow.com/homedetails/128-W-138th...    305898907
# 96806  https://www.zillow.com/homedetails/70-Park-Ter...   2064168641
# 96807  https://www.zillow.com/homedetails/77-Park-Ter...    122143341
# 96808  https://www.zillow.com/homedetails/77-Park-Ter...     80624971
#
#                                            address         street_name  \
# ...

# %%
zil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96809 entries, 0 to 96808
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   property_url        96809 non-null  object
#  1   property_id         96809 non-null  int64
#  2   address             96809 non-null  object
#  3   street_name         96802 non-null  object
#  4   apartment           12765 non-null  object
#  5   city                96809 non-null  object
#  6   state               96809 non-null  object
#  7   latitude            92392 non-null  float64
#  8   longitude           92392 non-null  float64
#  9   postcode            96807 non-null  float64
#  10  price               96809 non-null  float64
#  11  bedroom_number      87030 non-null  float64
#  12  bathroom_number     91152 non-null  float64
#  13  price_per_unit      69760 non-null  float64
#  14  living_space        70643 non-null  float64
# ...

# %%
# List of columns to drop from 'zil' DataFrame
columns_to_drop_zil = [
    'property_url', 
    'property_id', 
    'apartment', 
    'state', 
    'latitude', 
    'longitude', 
    'postcode', 
    'price_per_unit', 
    'land_space_unit', 
    'broker_id', 
    'property_status', 
    'year_build', 
    'total_num_units', 
    'listing_age', 
    'RunDate', 
    'agency_name', 
    'agent_name', 
    'agent_phone', 
    'is_owned_by_zillow', 
    'property_type'
]

# Drop the columns from the 'zil' DataFrame
zil_cleaned = zil.drop(columns=columns_to_drop_zil)

# Verify the changes
print(zil_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96809 entries, 0 to 96808
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          96809 non-null  object
#  1   street_name      96802 non-null  object
#  2   city             96809 non-null  object
#  3   price            96809 non-null  float64
#  4   bedroom_number   87030 non-null  float64
#  5   bathroom_number  91152 non-null  float64
#  6   living_space     70643 non-null  float64
#  7   land_space       67362 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 5.9+ MB
# None

# %%
zil_cleaned
# Out:
#                                            address         street_name  \
# 0                   97 Reservoir, Hawley, NY 18428           Reservoir
# 1             524 County Road 64, Elmira, NY 14903      County Road 64
# 2               32 Brookside Cir, Elmira, NY 14903       Brookside Cir
# 3        252 Elmwood Ave, Elmira Heights, NY 14903         Elmwood Ave
# 4      3526 Kentucky Ave, Elmira Heights, NY 14903        Kentucky Ave
# ...                                            ...                 ...
# 96804     333 Lathrop Ave, Staten Island, NY 10302         Lathrop Ave
# 96805       128 W 138th St #5I, New York, NY 10030      W 138th St #5I
# 96806         70 Park Ter E #6, New York, NY 10034       Park Ter E #6
# 96807    77 Park Ter E APT D76, New York, NY 10034  Park Ter E APT D76
# 96808    77 Park Ter E APT D35, New York, NY 10034  Park Ter E APT D35
#
#                  city     price  bedroom_number  bathroom_number  \
# ...

# %%
zil_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96809 entries, 0 to 96808
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          96809 non-null  object
#  1   street_name      96802 non-null  object
#  2   city             96809 non-null  object
#  3   price            96809 non-null  float64
#  4   bedroom_number   87030 non-null  float64
#  5   bathroom_number  91152 non-null  float64
#  6   living_space     70643 non-null  float64
#  7   land_space       67362 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 5.9+ MB

# %%
# Drop the 'living_space' and 'land_space' columns
zil_cleaned = zil_cleaned.drop(columns=['land_space'])

# Drop rows where 'bedroom_number' has NaN values
zil_cleaned = zil_cleaned.dropna(subset=['bedroom_number'])

# Verify the changes
print(zil_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87030 entries, 1 to 96808
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          87030 non-null  object
#  1   street_name      87026 non-null  object
#  2   city             87030 non-null  object
#  3   price            87030 non-null  float64
#  4   bedroom_number   87030 non-null  float64
#  5   bathroom_number  87020 non-null  float64
#  6   living_space     69280 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 5.3+ MB
# None

# %%
zil_cleaned = zil_cleaned.dropna()
zil_cleaned
# Out:
#                                            address         street_name  \
# 1             524 County Road 64, Elmira, NY 14903      County Road 64
# 2               32 Brookside Cir, Elmira, NY 14903       Brookside Cir
# 3        252 Elmwood Ave, Elmira Heights, NY 14903         Elmwood Ave
# 4      3526 Kentucky Ave, Elmira Heights, NY 14903        Kentucky Ave
# 5                235 Elmwood Ave, Elmira, NY 14903         Elmwood Ave
# ...                                            ...                 ...
# 96803      33 Rainbow Ave, Staten Island, NY 10302         Rainbow Ave
# 96804     333 Lathrop Ave, Staten Island, NY 10302         Lathrop Ave
# 96805       128 W 138th St #5I, New York, NY 10030      W 138th St #5I
# 96807    77 Park Ter E APT D76, New York, NY 10034  Park Ter E APT D76
# 96808    77 Park Ter E APT D35, New York, NY 10034  Park Ter E APT D35
#
#                  city     price  bedroom_number  bathroom_number  living_space
# ...

# %%
zil_cleaned.to_csv('NYH_1.csv', index=False)

# %%
df = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_5_Project\Customers_1.csv')

# %%
import pandas as pd
NYH = pd.read_csv(r'C:\Users\Sahan\Documents\Phase_5_Project\NY_Houses.csv', low_memory=False)
NYH
# Out:
#                address/city  address/community address/neighborhood  \
# 0                  New York                NaN                  NaN
# 1                     Bronx                NaN                  NaN
# 2                     Bronx                NaN                  NaN
# 3                     Bronx                NaN                  NaN
# 4                     Bronx                NaN                  NaN
# ...                     ...                ...                  ...
# 75625              Flushing                NaN                  NaN
# 75626  Forest Hills Gardens                NaN                  NaN
# 75627  Forest Hills Gardens                NaN                  NaN
# 75628              Flushing                NaN                  NaN
# 75629              Flushing                NaN                  NaN
#
#       address/state address/streetAddress address/subdivision  \
# 0                NY   60 Terrace View Ave                 NaN
# ...

# %%
NYH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75630 entries, 0 to 75629
# Data columns (total 1507 columns):
#  #     Column                                          Non-Null Count  Dtype
# ---    ------                                          --------------  -----
#  0     address/city                                    75629 non-null  object
#  1     address/community                               0 non-null      float64
#  2     address/neighborhood                            677 non-null    object
#  3     address/state                                   75629 non-null  object
#  4     address/streetAddress                           75629 non-null  object
#  5     address/subdivision                             2 non-null      object
#  6     address/zipcode                                 75611 non-null  float64
#  7     bathrooms                                       56577 non-null  float64
#  8     bedrooms                                        56166 non-null  float64
# ...

# %%
import pandas as pd

# Set the display option to show all columns in the info() output
pd.set_option('display.max_info_columns', 1507)  # Set it to the number of columns in your DataFrame

# Now you can use df.info() to display all columns
print(NYH.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75630 entries, 0 to 75629
# Data columns (total 1507 columns):
#  #     Column                                          Non-Null Count  Dtype
# ---    ------                                          --------------  -----
#  0     address/city                                    75629 non-null  object
#  1     address/community                               0 non-null      float64
#  2     address/neighborhood                            677 non-null    object
#  3     address/state                                   75629 non-null  object
#  4     address/streetAddress                           75629 non-null  object
#  5     address/subdivision                             2 non-null      object
#  6     address/zipcode                                 75611 non-null  float64
#  7     bathrooms                                       56577 non-null  float64
#  8     bedrooms                                        56166 non-null  float64
# ...

# %%
# Identify columns containing 'photo' in their name
columns_to_drop = NYH.filter(like='photo').columns

# Drop these columns from the DataFrame
NYH = NYH.drop(columns=columns_to_drop)


# Verify the changes
print(NYH.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75630 entries, 0 to 75629
# Data columns (total 1135 columns):
#  #     Column                                          Non-Null Count  Dtype
# ---    ------                                          --------------  -----
#  0     address/city                                    75629 non-null  object
#  1     address/community                               0 non-null      float64
#  2     address/neighborhood                            677 non-null    object
#  3     address/state                                   75629 non-null  object
#  4     address/streetAddress                           75629 non-null  object
#  5     address/subdivision                             2 non-null      object
#  6     address/zipcode                                 75611 non-null  float64
#  7     bathrooms                                       56577 non-null  float64
#  8     bedrooms                                        56166 non-null  float64
# ...

# %%
# Identify columns containing 'photo' in their name
columns_to_drop = NYH.filter(like='priceHistory').columns

# Drop these columns from the DataFrame
NYH = NYH.drop(columns=columns_to_drop)


# Verify the changes
print(NYH.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75630 entries, 0 to 75629
# Data columns (total 664 columns):
#  #    Column                                          Non-Null Count  Dtype
# ---   ------                                          --------------  -----
#  0    address/city                                    75629 non-null  object
#  1    address/community                               0 non-null      float64
#  2    address/neighborhood                            677 non-null    object
#  3    address/state                                   75629 non-null  object
#  4    address/streetAddress                           75629 non-null  object
#  5    address/subdivision                             2 non-null      object
#  6    address/zipcode                                 75611 non-null  float64
#  7    bathrooms                                       56577 non-null  float64
#  8    bedrooms                                        56166 non-null  float64
# ...

# %%
# Identify columns containing 'photo' in their name
columns_to_drop = NYH.filter(like='resoFactsStats').columns

# Drop these columns from the DataFrame
NYH = NYH.drop(columns=columns_to_drop)


# Verify the changes
print(NYH.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75630 entries, 0 to 75629
# Data columns (total 58 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   address/city                  75629 non-null  object
#  1   address/community             0 non-null      float64
#  2   address/neighborhood          677 non-null    object
#  3   address/state                 75629 non-null  object
#  4   address/streetAddress         75629 non-null  object
#  5   address/subdivision           2 non-null      object
#  6   address/zipcode               75611 non-null  float64
#  7   bathrooms                     56577 non-null  float64
#  8   bedrooms                      56166 non-null  float64
#  9   currency                      75630 non-null  object
#  10  dateposted                    23430 non-null  float64
#  11  description                   68944 non-null  object
# ...

# %%
# Identify columns containing 'photo' in their name
columns_to_drop = NYH.filter(like='schools').columns

# Drop these columns from the DataFrame
NYH = NYH.drop(columns=columns_to_drop)


# Verify the changes
print(NYH.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75630 entries, 0 to 75629
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   address/city           75629 non-null  object
#  1   address/community      0 non-null      float64
#  2   address/neighborhood   677 non-null    object
#  3   address/state          75629 non-null  object
#  4   address/streetAddress  75629 non-null  object
#  5   address/subdivision    2 non-null      object
#  6   address/zipcode        75611 non-null  float64
#  7   bathrooms              56577 non-null  float64
#  8   bedrooms               56166 non-null  float64
#  9   currency               75630 non-null  object
#  10  dateposted             23430 non-null  float64
#  11  description            68944 non-null  object
#  12  homeStatus             75630 non-null  object
#  13  latitude               75604 non-null  float64
# ...

# %%
# List of columns to drop
columns_to_drop = [
    'address/community', 
    'address/neighborhood', 
    'address/state', 
    'address/subdivision', 
    'dateposted', 
    'description', 
    'homeStatus', 
    'latitude', 
    'longitude', 
    'propertyTaxRate', 
    'url', 
    'zpid',
    'currency'
]

# Drop the columns from the DataFrame
NYH = NYH.drop(columns=columns_to_drop)

# Verify the changes
print(NYH.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75630 entries, 0 to 75629
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   address/city           75629 non-null  object
#  1   address/streetAddress  75629 non-null  object
#  2   address/zipcode        75611 non-null  float64
#  3   bathrooms              56577 non-null  float64
#  4   bedrooms               56166 non-null  float64
#  5   livingArea             66419 non-null  float64
#  6   price                  75591 non-null  float64
#  7   yearBuilt              69898 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 4.6+ MB
# None

# %%
# Drop rows where either 'bathrooms' or 'bedrooms' have NaN values
NYH = NYH.dropna(subset=['bathrooms', 'bedrooms','livingArea'])

# Verify the changesb
NYH
# Out:
#                address/city address/streetAddress  address/zipcode  bathrooms  \
# 0                  New York   60 Terrace View Ave          10463.0        2.0
# 1                     Bronx        625 W 246th St          10471.0        8.0
# 2                     Bronx        716 W 231st St          10463.0        3.0
# 3                     Bronx        750 W 232nd St          10463.0        6.0
# 5                  New York     24 Cooper St #5CD          10034.0        2.0
# ...                     ...                   ...              ...        ...
# 75622          Forest Hills        93-19 71st Ave          11375.0        2.0
# 75625              Flushing         6829 Manse St          11375.0        2.0
# 75626  Forest Hills Gardens       82 Greenway Ter          11375.0        6.0
# 75627  Forest Hills Gardens       86 Greenway Ter          11375.0        5.0
# 75629              Flushing         7049 Manse St          11375.0        2.0
#
# ...

# %%
NYH.to_csv(r'C:\Users\Sahan\Documents\Phase_5_Project\NYH_2.csv')
